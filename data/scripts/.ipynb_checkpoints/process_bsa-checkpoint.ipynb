# %% [markdown]
# # Notebook for process SASA data generated by run_dssp.ipynb:
#     /home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/dssp_sasa_noNA.csv

# %%
from Bio.PDB import *
import pandas as pd
import warnings
from Bio import BiopythonWarning
warnings.simplefilter('ignore', BiopythonWarning)
import csv
import numpy as np
from Bio.PDB.Polypeptide import three_to_one, one_to_three
import math
import multiprocessing as mp

# %% [markdown]
# ### Please provide the sasa file generated by run_dssp.

# %%
dssp_sasa_file = '/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/only2chains/dssp_sasa.csv'
df = pd.read_csv(dssp_sasa_file, index_col=0)

# clean NaN's
# df = pd.read_csv('dssp_sasa.csv',index_col=0)
print(df.shape[0])
df.dropna(inplace=True)
print(df.shape[0])
# df.to_csv('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/only2chains/dssp_sasa_noNA.csv')
# Out:
# 36466
# 35645

# %%
df.head()
# Out:
#   wt_name mu_name  Total_SASA_wt  SASA_wt_g1  SASA_wt_g2  Total_SASA_mu  \
# 0    10gs    1md4        17797.0      9785.0      9785.0        17597.0
# 1    10gs    3hjo        17797.0      9785.0      9785.0        18250.0
# 2    10gs    3ie3        17797.0      9785.0      9785.0        18099.0
# 3    117e    1e6a        22598.0     12174.0     12468.0        22407.0
# 4    117e    1huk        22598.0     12174.0     12468.0        23418.0
#
#    SASA_mu_g1  SASA_mu_g2 Chain_in_G1 Chain_in_G2
# 0     10090.0     10079.0           A           B
# 1     10511.0     10406.0           A           B
# 2     10386.0     10325.0           A           B
# 3     12287.0     12127.0           A           B
# 4     12508.0     12959.0           A           B

# %%
# df2 = df.drop(len(df.columns[-1]) > 1 or len(df.columns[-2]) > 1)

# %%
# df2.shape
# Out:
# (35642, 10)

# %%
df.to_csv('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/only2chains/dssp_sasa_noNA.csv')

# %%
# df = df.drop(df.columns[0], axis=1)

# %%
# df = pd.read_csv('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/dssp_sasa_noNA.csv')
df = pd.read_csv('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/only2chains/dssp_sasa_noNA.csv')

df = df.drop(df.columns[0], axis=1)
print(df.shape)
# Out:
# (35645, 10)

# %%
df.head()
# Out:
#   wt_name mu_name  Total_SASA_wt  SASA_wt_g1  SASA_wt_g2  Total_SASA_mu  \
# 0    10gs    1md4        17797.0      9785.0      9785.0        17597.0
# 1    10gs    3hjo        17797.0      9785.0      9785.0        18250.0
# 2    10gs    3ie3        17797.0      9785.0      9785.0        18099.0
# 3    117e    1e6a        22598.0     12174.0     12468.0        22407.0
# 4    117e    1huk        22598.0     12174.0     12468.0        23418.0
#
#    SASA_mu_g1  SASA_mu_g2 Chain_in_G1 Chain_in_G2
# 0     10090.0     10079.0           A           B
# 1     10511.0     10406.0           A           B
# 2     10386.0     10325.0           A           B
# 3     12287.0     12127.0           A           B
# 4     12508.0     12959.0           A           B

# %%
wts = df['wt_name']
mus = df['mu_name']

# %%
# pid_set = set(np.append(wts.values, mus.values))
# print("# of unique pids", len(pid_set))
# Out:
# # of unique pids 1797

# %%
pid_set = set(np.append(wts.values, mus.values))
print("# of unique pids", len(pid_set))
# Out:
# # of unique pids 10234

# %%
df.head(10)
df.shape
# Out:
# (35645, 10)

# %%
def download_all_pdb(pid_set):
    pdbl = PDBList()
    for elem in pid_set:
        print(elem)
        assert(len(elem) ==4)
        pdbl.retrieve_pdb_file(elem, pdir = '/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/pdbs/', file_format='pdb')
#         break

# %%
# download_all_pdb(pid_set)

# %% [markdown]
# Save score files

# %%
def get_seq_all(ent_names, chain_ID0, chain_ID1):
#     print(ent_names, chain_ID0, chain_ID1)
    parser = PDBParser()
    
    for ent_name in ent_names:
        structure = parser.get_structure(ent_name, '/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/pdbs/pdb'+ ent_name.lower() + '.ent')
    #     assert(len(structure) == 1)
        model = structure[0]

        w_name0 = ent_name+'_'+chain_ID0
        if w_name0 not in seq_dict:
            w_seq0 = ''

            chain0 = model[chain_ID0]
            ppb = PPBuilder()
            for pp in ppb.build_peptides(chain0):
                w_seq0 += pp.get_sequence()

            seq_dict[w_name0] = w_seq0
        
        
        w_name1 = ent_name+'_'+chain_ID1
        if w_name1 not in seq_dict:
            w_seq1 = ''

            chain1 = model[chain_ID1]
            ppb = PPBuilder()
            for pp in ppb.build_peptides(chain1):
                w_seq1 += pp.get_sequence()

            seq_dict[w_name1] = w_seq1
    return seq_dict

# %%
def get_seq_one(ent_names, chain_ID0):
#     print(ent_names, chain_ID0, chain_ID1)
    parser = PDBParser()
    
    for ent_name in ent_names:
        structure = parser.get_structure(ent_name, '/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/pdbs/pdb'+ ent_name.lower() + '.ent')
    #     assert(len(structure) == 1)
        model = structure[0]

        w_name0 = ent_name+'_'+chain_ID0
        w_seq0 = ''

        chain0 = model[chain_ID0]
        ppb = PPBuilder()
        for pp in ppb.build_peptides(chain0):
            w_seq0 += pp.get_sequence()
        print(ent_names, chain_ID0, w_seq0)

# %%
get_seq_one(['5gob'],'B')
# Out:
# ['5gob'] B

# %%
df_val = df.values
len(df_val)
# Out:
# 35645

# %%
df_val = df.values
# seq_dict = {}
# for i in range(len(df_val)):
for i in range(2870, len(df_val)):

# for i in range(10):
    if len(df_val[i][-2]) == 1 and len(df_val[i][-1]) == 1:
        if i %50 == 0:
            print(i, df_val[i])
        seq_dict = get_seq_all(df_val[i][:2], df_val[i][-2], df_val[i][-1])
    else:
        print("passing", df_val[i])
#     break
# Out:
# passing ['1dwo' '1eb8' 19304.0 10672.0 10454.0 19600.0 10926.0 10502.0 'A' 'BS']
# passing ['1dwo' '1eb9' 19304.0 10672.0 10454.0 19621.0 10908.0 10503.0 'A' 'BS']
# 2900 ['1dy5' '3euy' 13166.0 6891.0 6802.0 13533.0 6916.0 7219.0 'A' 'B']
# 2950 ['1dzh' '3evj' 33408.0 18157.0 17098.0 34244.0 18019.0 17836.0 'I' 'L']
# 3000 ['1e2p' '1ki6' 23435.0 13289.0 13598.0 21928.0 12653.0 12689.0 'A' 'B']
# 3050 ['1e4h' '2b16' 10827.0 6306.0 6344.0 10330.0 6084.0 6034.0 'A' 'B']
# 3100 ['1e5a' '3dk0' 11125.0 6459.0 6526.0 11607.0 6771.0 6698.0 'A' 'B']
# 3150 ['1ebl' '2gyo' 21082.0 12900.0 12796.0 22032.0 13370.0 13291.0 'A' 'B']
# 3200 ['1eby' '1zsf' 10101.0 6772.0 6883.0 9662.0 6559.0 6229.0 'A' 'B']
# 3250 ['1ec0' '1hiv' 9737.0 6471.0 6770.0 9728.0 6141.0 6546.0 'A' 'B']
# 3300 ['1ec2' '2p3b' 9901.0 6599.0 6814.0 9919.0 6694.0 6663.0 'A' 'B']
# 3350 ['1ed6' '3n6c' 34817.0 20028.0 20467.0 34855.0 20190.0 20025.0 'A' 'B']
# ...

# %%
len(seq_dict)
# Out:
# 20331

# %%
len(seq_dict)
# Out:
# 2175

# %%
# manager = mp.Manager()
# seq_dict = manager.dict()
# df_val = df.values
# # seq_dict = {}
# for batch in range(0,len(df_val), 500):
#     print("in batch:", batch)
#     processes = [mp.Process(target=get_seq_all, args=(df_val[i][:2], df_val[i][-2], df_val[i][-1])) for i in range(batch, min(batch+500, len(df_val)))]


# # # Run processes
# # for p in processes:
# #     p.start()

# # # Exit the completed processes
# # for p in processes:
# #     p.join()

# %%
print(len(seq_dict))
fout =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq_only2chains.txt', 'w+')
for k in seq_dict:
    print(k, seq_dict[k], sep = '\t', file = open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq_only2chains.txt', 'a'))
#     print(k)
#     print(w_name0, w_name1,mut_name0, mut_name1,dG_w, dG_m, dG_m - dG_w, file=open("./skempi.mut4.ddg.score.txt", "a"))
        
# len(df_val)
# Out:
# 20331

# %%
print(len(seq_dict))
fout =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq.txt', 'w+')
for k in seq_dict:
    print(k, seq_dict[k], sep = '\t', file = open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq.txt', 'a'))
#     print(k)
#     print(w_name0, w_name1,mut_name0, mut_name1,dG_w, dG_m, dG_m - dG_w, file=open("./skempi.mut4.ddg.score.txt", "a"))
        
# len(df_val)
# Out:
# 3594

# %%
# print(len(seq_dict))
# fout =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq.txt', 'w+')
# for k in seq_dict:
#     print(k, seq_dict[k], sep = '\t', file = open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq.txt', 'a'))
# #     print(k)
# #     print(w_name0, w_name1,mut_name0, mut_name1,dG_w, dG_m, dG_m - dG_w, file=open("./skempi.mut4.ddg.score.txt", "a"))
        
# # len(df_val)

# %%
seq_len = []
fout2 =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq_only2chains_filtered.txt', 'w+')
cnt_small = 0
small_pids = set()
for k in seq_dict:
    if len(seq_dict[k]) < 20:
        cnt_small+=1
#         print(k,len(seq_dict[k]),seq_dict[k])
        pid_small = k.split('_')[0]
#         print(pid_small)
        small_pids.add(pid_small)
        continue
    print(k, seq_dict[k], sep = '\t', file = open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq_only2chains_filtered.txt', 'a'))
    seq_len.append(len(seq_dict[k]))
    
print(cnt_small, len(small_pids))
# Out:
# 914 880

# %%
len(seq_dict)
# Out:
# 20331

# %%
len(seq_len)
# Out:
# 19417

# %%
dd_BSA = []
df_val = df.values
fout =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/asa_scores_only2chains_filtered.txt', 'w+')
for r in df_val:
#     print(r)
#     break
    p1 = r[0]+"_"+r[-2]
    p2 = r[0]+"_"+r[-1]
    p3 = r[1]+"_"+r[-2]
    p4 = r[1]+"_"+r[-1]
#     print(p1,p2,p3,p4)
    if p1 not in seq_dict or p2 not in seq_dict or p3 not in seq_dict or p4 not in seq_dict:
        print("passing",r)
#         print(seq_dict[r[0]], seq_dict[r[1]])
        continue
    BSA1 = r[2] - r[3] - r[4]
    BSA2 = r[5] - r[6] - r[7]
#     print(r[0]+'_'+r[-2],r[0]+'_'+r[-1],r[1]+'_'+r[-2], r[1]+'_'+r[-1],BSA1,BSA2, BSA1 - BSA2)
    if BSA1 - BSA2 < -2000 or BSA1 - BSA2 > 2000:
        continue
    print(r[0]+'_'+r[-2],r[0]+'_'+r[-1],r[1]+'_'+r[-2], r[1]+'_'+r[-1],BSA1,BSA2, BSA1 - BSA2, sep = '\t', file = open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/asa_scores_only2chains_filtered.txt', 'a'))
    dd_BSA.append(BSA1 - BSA2)
#     break
# Out:
# passing ['1dwo' '1eb8' 19304.0 10672.0 10454.0 19600.0 10926.0 10502.0 'A' 'BS']
# passing ['1dwo' '1eb9' 19304.0 10672.0 10454.0 19621.0 10908.0 10503.0 'A' 'BS']
# passing ['2c62' '4usg' 8383.0 5613.0 5653.0 8337.0 5655.0 5545.0 'A' 'BC']
# passing ['2iy5' '3hfz' 51163.0 20026.0 39453.0 45334.0 13965.0 39743.0 'A' 'BT']
# passing ['2iy5' '3teh' 51163.0 20026.0 39453.0 45869.0 13982.0 40266.0 'A' 'BT']
# passing ['2iy5' '4tva' 51163.0 20026.0 39453.0 45661.0 14015.0 39828.0 'A' 'BT']
# passing ['2qoe' '3h0c' 58355.0 31588.0 31383.0 59919.0 32050.0 32479.0 'A' 'BS']
# passing ['2qoe' '3kwf' 58355.0 31588.0 31383.0 59618.0 32017.0 32216.0 'A' 'BS']
# passing ['2qoe' '4jh0' 58355.0 31588.0 31383.0 58603.0 31561.0 31671.0 'A' 'BS']
# passing ['2qoe' '4lko' 58355.0 31588.0 31383.0 59196.0 31864.0 31911.0 'A' 'BS']
# passing ['2qoe' '5y7h' 58355.0 31588.0 31383.0 56559.0 30437.0 30721.0 'A' 'BS']
# passing ['2vlo' '2vlp' 12212.0 6320.0 7509.0 11402.0 5250.0 7768.0 'A' 'BS']
# ...

# %% [markdown]
# Seq Fasta file

# %%
seq_dict_fasta = {}
seq_len = []
print("loading")

fin =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/seq_filtered_fasta.txt', 'r')
for row in fin:
    a,b = row.strip().split('\t')
    if 'X' in b:
#         print('Skip', b)
        continue
    if len(b) < 20:
#         print('Skip', b)
        continue
    if a not in seq_dict_fasta:
        seq_dict_fasta[a] = b
        seq_len.append(len(b))
    elif seq_dict_fasta[a] != b:
        print("error", a, seq_dict_fasta[a], b)
        
#     print (a,b)
#     seq_dict_fasta[]
#     break
# Out:
# loading

# %%
len(seq_dict_fasta)
# Out:
# 3061

# %%
# Out:
# passing ['1aik' '2zzo' 5704.0 3604.0 3691.0 5951.0 3700.0 3774.0 'N' 'C']
# passing ['1alx' '1alz' 1604.0 1283.0 1308.0 1509.0 1281.0 1306.0 'A' 'B']
# passing ['1alx' '1bdw' 1604.0 1283.0 1308.0 1467.0 1311.0 1308.0 'A' 'B']
# passing ['1alx' '1grm' 1604.0 1283.0 1308.0 1660.0 922.0 933.0 'A' 'B']
# passing ['1alx' '1jo4' 1604.0 1283.0 1308.0 1577.0 884.0 892.0 'A' 'B']
# passing ['1alx' '1mag' 1604.0 1283.0 1308.0 1596.0 886.0 885.0 'A' 'B']
# passing ['1alx' '1mic' 1604.0 1283.0 1308.0 1432.0 1287.0 1280.0 'A' 'B']
# passing ['1alx' '1nru' 1604.0 1283.0 1308.0 1592.0 896.0 903.0 'A' 'B']
# passing ['1atp' '3qal' 15502.0 15283.0 2408.0 15679.0 15436.0 2069.0 'E' 'I']
# passing ['1awq' '1awu' 7303.0 7236.0 744.0 7576.0 7533.0 782.0 'A' 'B']
# passing ['1aws' '1awu' 7487.0 7356.0 756.0 7576.0 7533.0 782.0 'A' 'B']
# passing ['1b05' '1b0h' 19379.0 19673.0 545.0 19852.0 20206.0 410.0 'A' 'B']
# passing ['1b05' '1b1h' 19379.0 19673.0 545.0 19808.0 20149.0 410.0 'A' 'B']
# ...

# %%
# seq_len

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
 

num_bins = 80
n, bins, patches = plt.hist(seq_len, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
num_bins = 30
n, bins, patches = plt.hist(dd_BSA, num_bins, facecolor='red', alpha=0.5)
plt.show()

# %%
# sorted(dd_BSA)

# %%
dd_BSA = []
df_val = df.values
fout =  open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/asa_scores_filtered_fasta.txt', 'w+')
for r in df_val:
    if r[0] in small_pids or r[1] in small_pids:
        print("passing",r)
#         print(seq_dict[r[0]], seq_dict[r[1]])
        continue
    BSA1 = r[2] - r[3] - r[4]
    BSA2 = r[5] - r[6] - r[7]
#     print(r[0]+'_'+r[-2],r[0]+'_'+r[-1],r[1]+'_'+r[-2], r[1]+'_'+r[-1],BSA1,BSA2, BSA1 - BSA2)
    if BSA1 - BSA2 < -2000 or BSA1 - BSA2 > 2000:
        continue
    print(r[0]+'_'+r[-2],r[0]+'_'+r[-1],r[1]+'_'+r[-2], r[1]+'_'+r[-1],BSA1,BSA2, BSA1 - BSA2, sep = '\t', file = open('/home/zgy_ucla_cs/Research/Protein/PPI-Binding/bsa_data/asa_scores_filtered.txt', 'a'))
    dd_BSA.append(BSA1 - BSA2)
#     break
# Out:
# passing ['1a7f' '1hit' 3734.0 2133.0 2754.0 4075.0 1990.0 3057.0 'A' 'B']
# passing ['1aar' '5gob' 8047.0 4795.0 4754.0 4617.0 4740.0 186.0 'A' 'B']
# passing ['1aar' '5gog' 8047.0 4795.0 4754.0 4622.0 4568.0 213.0 'A' 'B']
# passing ['1aar' '5goj' 8047.0 4795.0 4754.0 4608.0 4579.0 357.0 'A' 'B']
# passing ['1aar' '5gok' 8047.0 4795.0 4754.0 4431.0 4489.0 341.0 'A' 'B']
# passing ['1aar' '5xdp' 8047.0 4795.0 4754.0 4394.0 4559.0 210.0 'A' 'B']
# passing ['1aik' '2zzo' 5704.0 3604.0 3691.0 5951.0 3700.0 3774.0 'N' 'C']
# passing ['1alx' '1alz' 1604.0 1283.0 1308.0 1509.0 1281.0 1306.0 'A' 'B']
# passing ['1alx' '1bdw' 1604.0 1283.0 1308.0 1467.0 1311.0 1308.0 'A' 'B']
# passing ['1alx' '1grm' 1604.0 1283.0 1308.0 1660.0 922.0 933.0 'A' 'B']
# passing ['1alx' '1jo4' 1604.0 1283.0 1308.0 1577.0 884.0 892.0 'A' 'B']
# passing ['1alx' '1mag' 1604.0 1283.0 1308.0 1596.0 886.0 885.0 'A' 'B']
# passing ['1alx' '1mic' 1604.0 1283.0 1308.0 1432.0 1287.0 1280.0 'A' 'B']
# ...

# %%
len_arr = []
for k in seq_dict:
    len_arr.append(len(seq_dict[k]))
